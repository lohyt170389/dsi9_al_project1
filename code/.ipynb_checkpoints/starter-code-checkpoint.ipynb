# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The new format for the SAT was released in March 2016. As an employee of the College Board - the organization that administers the SAT - you are a part of a team that tracks statewide participation and recommends where money is best spent to improve SAT participation rates.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:

import numpy as np
import scipy as stats
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:

sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:

print(sat_2017)
print(act_2017)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:The SAT data illustrates the participation rate for each states with the mean score of each section tested and the total mean score of the SAT test.
#
# The ACT data illustrates the participation rate for each states with the average score of each section tested and average score of the 4 sections.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: No. Based on the reports, there are informations (E.g Race, Sex, SAT Fee Waiver,etc) are missing.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: For ACT, maximum possible value for each test is 36 while minimum possible value for each test is 1.
# For SAT, for each section the minimum possible value is 200 while maximum possible value is 800.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# #code
# The type of data SAT are interger while the type of data for ACT are floats.

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
print(sat_2017.dtypes)
print(act_2017.dtypes)
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: Data type for Participation and Composite are object instead of float/integer.

# %% [markdown]
# # 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def incorrect_dtypes(data,char):
        return data.map(lambda i: float(i.replace(char, '')))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
sat_2017.Participation = incorrect_dtypes(sat_2017.Participation,'%')
act_2017.Participation = incorrect_dtypes(act_2017.Participation, '%')

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act_2017.Composite = incorrect_dtypes(act_2017.Composite, 'x')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print(sat_2017.dtypes)
print(act_2017.dtypes)
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way.
# Guidelines:
# Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition to df['column_name'].
# Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
new_sat_columns_list = {'State': 'state',
                        'Participation': 'sat_participation_2017',
                        'Evidence-Based Reading and Writing': 'sat_reading_and_writing_2017',
                        'Math': 'sat_math_2017',
                        'Total': 'sat_total_2017'}
new_act_columns_list = {'State' :'state', 
                       'Participation':'act_participation_2017', 
                       'English': 'act_english_2017', 
                       'Math' : 'act_math_2017', 
                       'Reading' : 'act_reading_2017', 
                       'Science' : 'act_science_2017',
                       'Composite': 'act_total_2017'}

sat_2017.rename(columns=new_sat_columns_list, inplace=True)
act_2017.rename(columns=new_act_columns_list, inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT&SAT|State name|
# |sat_participation_2017|float|SAT|Participation rate for 2017|
# |sat_reading_and_writing_2017|int|SAT|Average Reading and Writing score for 2017|
# |sat_math_2017|int|SAT|Average Math score for 2017|
# |sat_total_2017|int|SAT|Average Total score for 2017|
# |act_participation_2017|float|ACT|Average Participation rate for 2017|
# |act_english_2017|float|ACT|Average English score for 2017|
# |act_math_2017|float|ACT|Average Math score for 2017|
# |act_reading_2017|float|ACT|Average Reading score for 2017|
# |act_science_2017|float|ACT|Average Science score for 2017|
# |act_total_2017|float|ACT|Average Total score for 2017|
# |sat_participation_2018|float|SAT|Participation rate for 2018|
# |sat_reading_and_writing_2018|int|SAT|Average Reading and Writing score for 2018|
# |sat_math_2018|int|SAT|Average Math score for 2018|
# |sat_total_2018|int|SAT|Average Total score for 2018|
# |act_participation_2018|float|ACT|Participation rate for 2018|
# |act_english_2018|float|ACT|Average English score for 2018|
# |act_math_2018|float|ACT|Average Math score for 2018|
# |act_reading_2018|float|ACT|Average Reading score for 2018|
# |act_science_2018|float|ACT|Average Science score for 2018|
# |act_total_2018|float|ACT|Average Total score for 2018|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act_2017 = act_2017.drop(act_2017.index[0]) #drop the row 0

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
combined_2017 = pd.merge(sat_2017, act_2017, on="state", how="outer")

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv') # importing the sat_2018 file 
act_2018 = pd.read_csv('../data/act_2018.csv') # importing the act_2018 file

# %%
#checking the dtypes
print(sat_2018.dtypes)
print(act_2018.dtypes)
# Out:
# state                           object
# sat_participation_2018          object
# sat_reading_and_writing_2018     int64
# sat_math_2018                    int64
# sat_total_2018                   int64
# dtype: object
# state                      object
# act_participation_2018    float64
# act_english_2018          float64
# act_math_2018             float64
# act_reading_2018          float64
# act_science_2018          float64
# act_total_2018            float64
# dtype: object

# %%
sat_2018 = sat_2018.drop(sat_2018.index[[39,47]])
act_2018 = act_2018.drop(act_2018.index[[27]])

# %%
# removing the %
sat_2018.sat_participation_2018 = incorrect_dtypes(sat_2018.sat_participation_2018,'%')

# %%
combined_2018 = pd.merge(sat_2018, act_2018, on="state", how="outer") #combine act and sat

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_1718 = pd.merge(combined_2017, combined_2018, on="state", how="outer")
combined_1718.to_csv('final.csv')
combined_1718.dtypes
# Out:
# state                            object
# sat_participation_2017          float64
# sat_reading_and_writing_2017      int64
# sat_math_2017                     int64
# sat_total_2017                    int64
# act_participation_2017          float64
# act_english_2017                float64
# act_math_2017                   float64
# act_reading_2017                float64
# act_science_2017                float64
# act_total_2017                  float64
# sat_participation_2018          float64
# sat_reading_and_writing_2018      int64
# sat_math_2018                     int64
# sat_total_2018                    int64
# act_participation_2018          float64
# act_english_2018                float64
# act_math_2018                   float64
# act_reading_2018                float64
# act_science_2018                float64
# act_total_2018                  float64
# dtype: object

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
combined_1718.describe()
# Out:
#        sat_participation_2017  sat_reading_and_writing_2017  sat_math_2017  \
# count               51.000000                     51.000000      51.000000
# mean                39.803922                    569.117647     547.627451
# std                 35.276632                     45.666901      84.909119
# min                  2.000000                    482.000000      52.000000
# 25%                  4.000000                    533.500000     522.000000
# 50%                 38.000000                    559.000000     548.000000
# 75%                 66.000000                    613.000000     599.000000
# max                100.000000                    644.000000     651.000000
#
#        sat_total_2017  act_participation_2017  act_english_2017  \
# count       51.000000               51.000000         51.000000
# mean      1126.098039               65.254902         20.931373
# std         92.494812               32.140842          2.353677
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def calculate_std(n):
    mean = sum(n)/len(n)
    value = 0
    normaliser= 1/(len(n)-1)
    for i in n:
        value += (i - mean)**2
    return((normaliser*value)**0.5)

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
combined_1718_wostate = combined_1718.drop('state',axis=1)
dict_sd = combined_1718_wostate.to_dict('list')
sd = {k:calculate_std(v) for k,v in dict_sd.items()}
print(sd)
# Out:
# {'sat_participation_2017': 35.276632270013046, 'sat_reading_and_writing_2017': 45.66690138768932, 'sat_math_2017': 84.90911865855486, 'sat_total_2017': 92.49481172519046, 'act_participation_2017': 32.14084201588683, 'act_english_2017': 2.35367713980303, 'act_math_2017': 1.9819894936505533, 'act_reading_2017': 2.0672706264873146, 'act_science_2017': 3.182462975155452, 'act_total_2017': 2.020694891154341, 'sat_participation_2018': 38.0141872380898, 'sat_reading_and_writing_2018': 45.31767607353539, 'sat_math_2018': 49.21396262898426, 'sat_total_2018': 94.44221389138377, 'act_participation_2018': nan, 'act_english_2018': 2.4463562339793055, 'act_math_2018': 2.035764538177723, 'act_reading_2018': 2.1672445684804105, 'act_science_2018': 1.8701137639716146, 'act_total_2018': 2.1062781969951776}

# %%
#numpy std
sd1 = [np.std(combined_1718['sat_participation_2017'])]
print(sd1)
# Out:
# [34.92907076664508]

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: Both manual and numpy's std method resulted similar values.

# %%
combined_1718.sort_values("sat_participation_2017").head(10)
combined_1718.sort_values("sat_participation_2017").tail(10)
combined_1718.sort_values("sat_participation_2018").head(10)
combined_1718.sort_values("sat_participation_2018").tail(10)
combined_1718.sort_values("act_participation_2017").head(10)
combined_1718.sort_values("act_participation_2017").tail(25)
combined_1718.sort_values("act_participation_2018").head(10)
combined_1718.sort_values("act_participation_2018").tail(20)
# Out:
#              state  sat_participation_2017  sat_reading_and_writing_2017  \
# 34    North Dakota                     2.0                           635
# 23       Minnesota                     3.0                           644
# 44            Utah                     3.0                           624
# 42       Tennessee                     5.0                           623
# 0          Alabama                     5.0                           593
# 24     Mississippi                     2.0                           634
# 35            Ohio                    12.0                           578
# 28          Nevada                    26.0                           563
# 27        Nebraska                     3.0                           629
# 26         Montana                    10.0                           605
# 25        Missouri                     3.0                           640
# 49       Wisconsin                     3.0                           642
# ...

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT? - Lowest:North Dakota, Mississippi, Lowa. Highest:Michigan, District of Columbia, Delaware, Connecticut
#     - 2018 SAT? - Lowest:North Dakota. Highest:Colorado, Connecticut, Delaware, Michigan, Idaho
#     - 2017 ACT? - Lowest:Maine. Highest:South Carolina, Utah, Tennessee, Alabama, Missouri, North Carolina, Nevada, Montana, Wisconsin, Mississippi, Minnesota, Louisiana, Kentucky, COlorado, Arkansas, Oklahoma, Wyoming
#     - 2018 ACT? - Lowest: Maine. Highest:Alabama, Arkansas,Kentucky,Mississippi,Missouri,Montana,Nebraska,Nevada,Ohio,South Carolina,Tennessee,Utah,Wisconsin,Wyoming
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT? - Lowest:District of Columbia. Highest:Minnesota
#     - 2018 SAT? - Lowest:District of Columbia. Highest:Minnesota
#     - 2017 ACT? - Lowest:Nevada. Highest:New Hampshire
#     - 2018 ACT? - Lowest:Nevada. Higest:Connecticut
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Sorting
combined_1718.sort_values("sat_participation_2017").head(10)
combined_1718.sort_values("sat_participation_2017").tail(10)
# Out:
#                    state  sat_participation_2017  \
# 39          Rhode Island                    71.0
# 21         Massachusetts                    76.0
# 9                Florida                    83.0
# 12                 Idaho                    93.0
# 19                 Maine                    95.0
# 29         New Hampshire                    96.0
# 22              Michigan                   100.0
# 8   District of Columbia                   100.0
# 7               Delaware                   100.0
# 6            Connecticut                   100.0
#
#     sat_reading_and_writing_2017  sat_math_2017  sat_total_2017  \
# 39                           539            524            1062
# 21                           555            551            1107
# 9                            520            497            1017
# 12                           513            493            1005
# 19                           513            499            1012
# ...

# %% [markdown]
# 2017 SAT? - Lowest:North Dakota, Mississippi, Lowa. Highest:Michigan, District of Columbia, Delaware, Connecticut

# %%
combined_1718.sort_values("sat_participation_2018").head(10)
combined_1718.sort_values("sat_participation_2018").tail(10)
# Out:
#             state  sat_participation_2017  sat_reading_and_writing_2017  \
# 29  New Hampshire                    96.0                           532
# 9         Florida                    83.0                           520
# 39   Rhode Island                    71.0                           539
# 19          Maine                    95.0                           513
# 13       Illinois                     9.0                           559
# 5        Colorado                    11.0                           606
# 6     Connecticut                   100.0                           530
# 7        Delaware                   100.0                           503
# 22       Michigan                   100.0                           509
# 12          Idaho                    93.0                           513
#
#     sat_math_2017  sat_total_2017  act_participation_2017  act_english_2017  \
# 29            520            1052                    18.0              25.4
# ...

# %% [markdown]
# 2018 SAT? - Lowest:North Dakota. Highest:Colorado, Connecticut, Delaware, Michigan, Idaho

# %%
combined_1718.sort_values("act_participation_2017").head(10)
combined_1718.sort_values("act_participation_2017").tail(25)
# Out:
#              state  sat_participation_2017  sat_reading_and_writing_2017  \
# 16          Kansas                     4.0                           632
# 9          Florida                    83.0                           520
# 35            Ohio                    12.0                           578
# 41    South Dakota                     3.0                           612
# 27        Nebraska                     3.0                           629
# 11          Hawaii                    55.0                           544
# 13        Illinois                     9.0                           559
# 34    North Dakota                     2.0                           635
# 40  South Carolina                    50.0                           543
# 44            Utah                     3.0                           624
# 42       Tennessee                     5.0                           623
# 0          Alabama                     5.0                           593
# ...

# %% [markdown]
# 2017 ACT? - Lowest:Maine. Highest:South Carolina, Utah, Tennessee, Alabama, Missouri, North Carolina, Nevada, Montana, Wisconsin, Mississippi, Minnesota, Louisiana, Kentucky, COlorado, Arkansas, Oklahoma, Wyoming

# %%
combined_1718.sort_values("act_participation_2018").head(10)
combined_1718.sort_values("act_participation_2018").tail(20)
# Out:
#              state  sat_participation_2017  sat_reading_and_writing_2017  \
# 34    North Dakota                     2.0                           635
# 23       Minnesota                     3.0                           644
# 44            Utah                     3.0                           624
# 42       Tennessee                     5.0                           623
# 0          Alabama                     5.0                           593
# 24     Mississippi                     2.0                           634
# 35            Ohio                    12.0                           578
# 28          Nevada                    26.0                           563
# 27        Nebraska                     3.0                           629
# 26         Montana                    10.0                           605
# 25        Missouri                     3.0                           640
# 49       Wisconsin                     3.0                           642
# ...

# %% [markdown]
# 2018 ACT? - Lowest: Maine. Highest:Alabama,Arkansas,Kentucky,Mississippi,Missouri,Montana,Nebraska,Nevada,Ohio,South Carolina,Tennessee,Utah,Wisconsin,Wyoming

# %%
combined_1718.sort_values("sat_total_2017").head()
combined_1718.sort_values("sat_total_2017").tail()
# Out:
#         state  sat_participation_2017  sat_reading_and_writing_2017  \
# 16     Kansas                     4.0                           632
# 25   Missouri                     3.0                           640
# 15       Iowa                     2.0                           641
# 49  Wisconsin                     3.0                           642
# 23  Minnesota                     3.0                           644
#
#     sat_math_2017  sat_total_2017  act_participation_2017  act_english_2017  \
# 16            628            1260                    73.0              21.1
# 25            631            1271                   100.0              19.8
# 15            635            1275                    67.0              21.2
# 49            649            1291                   100.0              19.7
# 23            651            1295                   100.0              20.4
#
#     act_math_2017  act_reading_2017  act_science_2017  ...  \
# ...

# %% [markdown]
# 2017 SAT? - Lowest:District of Columbia. Highest:Minnesota

# %%
combined_1718.sort_values("sat_total_2018").head()
combined_1718.sort_values("sat_total_2018").tail()
# Out:
#            state  sat_participation_2017  sat_reading_and_writing_2017  \
# 16        Kansas                     4.0                           632
# 15          Iowa                     2.0                           641
# 34  North Dakota                     2.0                           635
# 49     Wisconsin                     3.0                           642
# 23     Minnesota                     3.0                           644
#
#     sat_math_2017  sat_total_2017  act_participation_2017  act_english_2017  \
# 16            628            1260                    73.0              21.1
# 15            635            1275                    67.0              21.2
# 34            621            1256                    98.0              19.0
# 49            649            1291                   100.0              19.7
# 23            651            1295                   100.0              20.4
#
#     act_math_2017  act_reading_2017  act_science_2017  ...  \
# ...

# %% [markdown]
# 2018 SAT? - Lowest:District of Columbia. Highest:Minnesota

# %%
combined_1718.sort_values("act_total_2017").head()
combined_1718.sort_values("act_total_2017").tail()
# Out:
#                    state  sat_participation_2017  \
# 8   District of Columbia                   100.0
# 19                 Maine                    95.0
# 6            Connecticut                   100.0
# 21         Massachusetts                    76.0
# 29         New Hampshire                    96.0
#
#     sat_reading_and_writing_2017  sat_math_2017  sat_total_2017  \
# 8                            482            468             950
# 19                           513            499            1012
# 6                            530            512            1041
# 21                           555            551            1107
# 29                           532            520            1052
#
#     act_participation_2017  act_english_2017  act_math_2017  act_reading_2017  \
# 8                     32.0              24.4           23.5              24.9
# 19                     8.0              24.2           24.0              24.8
# ...

# %% [markdown]
# 2017 ACT? - Lowest:Nevada. Highest:New Hampshire

# %%
combined_1718.sort_values("act_total_2018").head()
combined_1718.sort_values("act_total_2018").tail()
# Out:
#             state  sat_participation_2017  sat_reading_and_writing_2017  \
# 22       Michigan                   100.0                           509
# 32       New York                    67.0                           528
# 29  New Hampshire                    96.0                           532
# 21  Massachusetts                    76.0                           555
# 6     Connecticut                   100.0                           530
#
#     sat_math_2017  sat_total_2017  act_participation_2017  act_english_2017  \
# 22            495            1005                    29.0              24.1
# 32            523            1052                    31.0              23.8
# 29            520            1052                    18.0              25.4
# 21            551            1107                    29.0              25.4
# 6             512            1041                    31.0              25.5
#
#     act_math_2017  act_reading_2017  act_science_2017  ...  \
# ...

# %% [markdown]
# 2018 ACT? - Lowest:Nevada. Higest:Connecticut

# %%
participation_compare = combined_1718.mask(combined_1718['sat_participation_2017']<99).sort_values("sat_participation_2017").loc[:,['state','sat_participation_2017','sat_participation_2018']]
participation_compare.head()
# Out:
#                    state  sat_participation_2017  sat_participation_2018
# 6            Connecticut                   100.0                   100.0
# 7               Delaware                   100.0                   100.0
# 8   District of Columbia                   100.0                    92.0
# 22              Michigan                   100.0                   100.0
# 0                    NaN                     NaN                     NaN

# %% [markdown]
# Yes,District of Columbia

# %%
participation_compare1 = combined_1718.loc[:,['sat_participation_2017','act_participation_2017','sat_participation_2018','act_participation_2018']]
participation_compare1.where(participation_compare1>50).sort_values("sat_participation_2017").dropna(axis=0)
# Out:
#     sat_participation_2017  act_participation_2017  sat_participation_2018  \
# 11                    55.0                    90.0                    56.0
# 10                    61.0                    55.0                    70.0
# 9                     83.0                    73.0                    97.0
#
#     act_participation_2018
# 11                    89.0
# 10                    53.0
# 9                     66.0

# %% [markdown]
# yes, there are three states.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax = plt.axes()

ax.set_title('Correlation', fontsize=20)
sns.heatmap(combined_1718.corr(), annot=True, ax=ax);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize=(15,8)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings      
        ax[i].set_title(list_of_titles[i], fontsize=10)
        ax[i].set_xlabel(list_of_xlabels, fontsize=10)
        ax[i].set_ylabel('Occurance', fontsize=10)
    fig.tight_layout()

# Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Participation rates for SAT & ACT

subplot_histograms(combined_1718, ['sat_participation_2017','act_participation_2017','sat_participation_2018','act_participation_2018'], ['sat participation 2017','act participation 2017','sat participation 2018','act participation 2018'], 'Participation Rate')
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Math scores for SAT & ACT

subplot_histograms(combined_1718, ['sat_math_2017','act_math_2017','sat_math_2018','act_math_2018'], ['sat math 2017','act math 2017','sat math 2018','act math 2018'], 'math score')

# %%
# Reading/verbal scores for SAT & ACT

subplot_histograms(combined_1718, ['sat_reading_and_writing_2017','act_reading_2017','sat_reading_and_writing_2018','act_reading_2018'], ['sat reading_and_writing 2017','act reading 2017','sat reading_and_writing 2018','act reading 2018'], 'reading score')

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('Correlation for math score', fontsize=20)

sns.scatterplot(x=combined_1718["sat_math_2017"], y=combined_1718["act_math_2017"]);

# %%
# Code
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('Correlation for reading score', fontsize=20)

sns.scatterplot(x=combined_1718["sat_reading_and_writing_2017"], y=combined_1718["act_reading_2017"]);

# %%
# Code
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('Correlation for total score', fontsize=20)

sns.scatterplot(x=combined_1718["sat_total_2017"], y=combined_1718["act_total_2017"]);

# %%
# Code
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('Correlation for SAT total', fontsize=20)

sns.scatterplot(x=combined_1718["sat_total_2017"], y=combined_1718["sat_total_2018"]);

# %%
# Code
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('Correlation for ACT total', fontsize=20)

sns.scatterplot(x=combined_1718["act_total_2017"], y=combined_1718["act_total_2018"]);

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('Participation Rate', fontsize=20)

variable = combined_1718.loc[:,['sat_participation_2017','act_participation_2017','sat_participation_2018','act_participation_2018']]
sns.boxplot(data=variable);

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('SAT Total Score', fontsize=20)

variable = combined_1718.loc[:,['sat_total_2017','sat_total_2018']]
sns.boxplot(data=variable);

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax = plt.axes()
ax.set_title('SAT Individual Score', fontsize=20)

variable = combined_1718.loc[:,['sat_reading_and_writing_2017','sat_math_2017','sat_reading_and_writing_2018', 'sat_math_2018']]
sns.boxplot(data=variable);

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax = plt.axes()
ax.set_title('ACT Scores', fontsize=20)

variable = combined_1718.loc[:,['act_english_2017', 'act_math_2017','act_reading_2017','act_science_2017', 'act_total_2017',
                               'act_english_2018', 'act_math_2018', 'act_reading_2018','act_science_2018', 'act_total_2018']]
sns.boxplot(data=variable);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax = plt.axes()
ax.set_title('Participation Rates', fontsize=20)

combined_1718.sat_participation_2017.plot();

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax = plt.axes()
ax.set_title('Math Score', fontsize=20)

combined_1718.sat_math_2017.plot();

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:The data sampled does not seem normally distributed.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No. The score was tabulated based on different numeric scales.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?
